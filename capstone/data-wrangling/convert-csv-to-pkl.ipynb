# %%
import pandas as pd

# %%
#df = pd.read_csv('../data/ALL.csv', index_col = 10, low_memory = False, parse_dates = True, nrows = 5)
df = pd.read_csv('../data/ALL.csv', index_col = False, low_memory = False, parse_dates = [10])
df.head()
#df.drop(columns = 'contb_receipt_dt', inplace = True)
#df.index.rename('date', inplace = True)
#df.sort_index()
#df.contb_receipt_dt
df.set_index('contb_receipt_dt', inplace = True)
df.sort_index(inplace = True)
df.head()
# Out:
#                     cmte_id    cand_id           cand_nm  \
# contb_receipt_dt
# 2006-08-30        C00580100  P80001571  Trump, Donald J.
# 2013-10-01        C00458844  P60006723      Rubio, Marco
# 2013-10-01        C00458844  P60006723      Rubio, Marco
# 2013-10-04        C00458844  P60006723      Rubio, Marco
# 2013-10-04        C00458844  P60006723      Rubio, Marco
#
#                                   contbr_nm    contbr_city contbr_st  \
# contb_receipt_dt
# 2006-08-30             FOSTER, SYLVIA L DR.     MIDDLETOWN        DE
# 2013-10-01        MARGULIES, STANLEY I. DR.     ISLAMORADA        FL
# 2013-10-01        MARGULIES, STANLEY I. DR.     ISLAMORADA        FL
# 2013-10-04               ACOSTA, ADELFA MS.  MIAMI SPRINGS        FL
# 2013-10-04               ZOLDAN, GERALD MR.        CHICAGO        IL
#
#                  contbr_zip           contbr_employer contbr_occupation  \
# contb_receipt_dt
# 2006-08-30            19709                  N.P.H.S.         PHYSICIAN
# ...

# %%
df.to_pickle('../data/ALL.pkl')
