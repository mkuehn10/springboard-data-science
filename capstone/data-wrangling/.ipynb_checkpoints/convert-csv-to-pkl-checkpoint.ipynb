# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df = pd.read_csv('../data/ALL.csv', index_col = 10, low_memory = False, parse_dates = True, nrows = 5)
df = pd.read_csv('../data/ALL.csv', index_col = False, low_memory = False, parse_dates = [10], nrows = 5)
df.head()
#df.drop(columns = 'contb_receipt_dt', inplace = True)
#df.index.rename('date', inplace = True)
#df.sort_index()
#df.contb_receipt_dt
df.set_index('contb_receipt_dt', inplace = True)
df.sort_index()
# Out:
#                     cmte_id    cand_id       cand_nm            contbr_nm  \
# contb_receipt_dt
# 2016-02-20        C00458844  P60006723  Rubio, Marco    CHILDERS, WILLIAM
# 2016-03-08        C00458844  P60006723  Rubio, Marco     RUCINSKI, ROBERT
# 2016-03-10        C00458844  P60006723  Rubio, Marco     RUCINSKI, ROBERT
# 2016-03-15        C00458844  P60006723  Rubio, Marco        BLUM, MAUREEN
# 2016-03-16        C00458844  P60006723  Rubio, Marco  DODSON, MARK B. MR.
#
#                  contbr_city contbr_st contbr_zip  \
# contb_receipt_dt
# 2016-02-20               DPO        AE  098309998
# 2016-03-08               APO        AE  090960009
# 2016-03-10               APO        AE  090960009
# 2016-03-15        WASHINGTON        20         DC
# 2016-03-16           ATLANTA        30         GA
#
#                                         contbr_employer  \
# contb_receipt_dt
# 2016-02-20                                     DIPLOMAT
# 2016-03-08                                      US ARMY
# 2016-03-10                                      US ARMY
# 2016-03-15        STRATEGIC COALITIONS & INITIATIVES LL
# 2016-03-16                    MORTGAGE CAPITAL ADVISORS
#
#                          contbr_occupation  contb_receipt_amt  receipt_desc  \
# contb_receipt_dt
# 2016-02-20                   US GOVERNMENT                100           NaN
# 2016-03-08                       PHYSICIAN                100           NaN
# 2016-03-10                       PHYSICIAN                200           NaN
# 2016-03-15               OUTREACH DIRECTOR                175           NaN
# 2016-03-16        PRIVATE MORTGAGE BANKING                 25           NaN
#
#                   memo_cd        memo_text form_tp  file_num       tran_id  \
# contb_receipt_dt
# 2016-02-20            NaN              NaN   SA17A   1056862  SA17.1020839
# 2016-03-08            NaN              NaN   SA17A   1082559  SA17.1074981
# 2016-03-10            NaN              NaN   SA17A   1082559  SA17.1078677
# 2016-03-15            NaN              NaN   SA17A   1082559  SA17.1152124
# 2016-03-16            NaN  DEBT RETIREMENT   SA17A   1082559  SA17.1153048
#
#                  election_tp
# contb_receipt_dt
# 2016-02-20             P2016
# 2016-03-08             P2016
# 2016-03-10             P2016
# 2016-03-15             P2016
# 2016-03-16             P2016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2016-03-15 to 2016-03-08
# Data columns (total 17 columns):
# cmte_id              5 non-null object
# cand_id              5 non-null object
# cand_nm              5 non-null object
# contbr_nm            5 non-null object
# contbr_city          5 non-null object
# contbr_st            5 non-null object
# contbr_zip           5 non-null object
# contbr_employer      5 non-null object
# contbr_occupation    5 non-null object
# contb_receipt_amt    5 non-null int64
# receipt_desc         0 non-null float64
# memo_cd              0 non-null float64
# memo_text            1 non-null object
# form_tp              5 non-null object
# file_num             5 non-null int64
# tran_id              5 non-null object
# election_tp          5 non-null object
# dtypes: float64(2), int64(2), object(13)
# memory usage: 720.0+ bytes

# %%
plt.hist(df['contb_receipt_amt'])
plt.show()
plt.clf()
plt.plot(df['contb_receipt_amt'])

# %%
df.to_pickle('../data/ALL.pkl')
